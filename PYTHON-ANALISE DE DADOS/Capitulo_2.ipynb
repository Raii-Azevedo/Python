# %% [markdown]
# # 📘 Python para Análise de Dados — Capítulo 2
# _📖 Por Wes McKinney_
#
# Muito bom poder dar continuidade ao mergulho no livro do Wes McKinney! O mais legal é que alguns conceitos do capítulo acabaram sendo **aplicados imediatamente em um projeto real**.
#
# Estava às pressas para apresentar um mockup e percebi que os valores do meu dataset estavam **muito balanceados**, o que não gerava um visual interessante. Para resolver, utilizei o `sample` do Pandas e algumas funções auxiliares, modificando **mais de 1 milhão de linhas** e criando um CSV muito mais realista para a simulação.
#
# ## 💻 Código utilizado:

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Ler arquivo original
df = pd.read_csv("file_for_bi.csv")

# Intervalo de datas
start_date = datetime(2024, 8, 1)
end_date = datetime(2025, 7, 31)

# Função para gerar data aleatória no intervalo
def random_date(start, end):
    return start + timedelta(days=np.random.randint(0, (end - start).days + 1))

df['propensity_date'] = [random_date(start_date, end_date).strftime('%Y-%m-%d') for _ in range(len(df))]

# Criar variedade nos scores
scores = []
for _ in range(len(df)):
    p = np.random.rand()
    if p < 0.4:   # 40% dos casos -> extremos
        scores.append(np.random.beta(0.5, 0.5))
    elif p < 0.7: # 30% dos casos -> médios
        scores.append(np.random.normal(0.5, 0.15))
    else:         # 30% dos casos -> uniformemente distribuídos
        scores.append(np.random.rand())

# Garantir que fiquem dentro de [0,1]
df['propensity_score'] = np.clip(scores, 0, 1)

# Salvar
df.to_csv("seu_arquivo_modificado.csv", index=False)

print("✅ Dados mais variados gerados!")

# %% [markdown]
# Com isso, consegui resolver a questão do balanço de dados apenas 15 minutos antes da apresentação. 🚀
#
# 📖 O que o Capítulo 2 traz
#
# O conteúdo do capítulo foi mais introdutório, mas cheio de detalhes importantes para quem está começando ou revisando conceitos de Python. Alguns destaques:
#
# 🔹 Uso de interpretadores Python
#
# Preenchimento automático com tabulação
#
# Introspecção usando ? para inspecionar objetos
#
# 🔹 Conceitos básicos da linguagem
#
# Semântica
#
# Variáveis
#
# Referências dinâmicas
#
# Atributos e métodos
#
# ✨ Agora sigo para o Capítulo 3, que entra em estruturas de dados — um dos pontos que mais impactam a forma como manipulamos informação em Python.
